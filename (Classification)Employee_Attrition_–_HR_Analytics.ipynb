# %% [markdown]
# <a href="https://colab.research.google.com/github/shahdelmasry12/Data-Mining-Project/blob/main/(Classification)Employee_Attrition_%E2%80%93_HR_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Load Data**

# %%
#Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
url = "https://raw.githubusercontent.com/shahdelmasry12/Data-Mining-Project/refs/heads/main/WA_Fn-UseC_-HR-Employee-Attrition.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# # ***Cleaning data***

# %%
df.head().T #To display all columns with the first five rows
# Out:
#                                         0                       1  \
# Age                                    41                      49
# Attrition                             Yes                      No
# BusinessTravel              Travel_Rarely       Travel_Frequently
# DailyRate                            1102                     279
# Department                          Sales  Research & Development
# DistanceFromHome                        1                       8
# Education                               2                       1
# EducationField              Life Sciences           Life Sciences
# EmployeeCount                           1                       1
# EmployeeNumber                          1                       2
# EnvironmentSatisfaction                 2                       3
# Gender                             Female                    Male
# HourlyRate                             94                      61
# ...

# %%
df.shape #to get number of (Rows,Columns)
# Out:
# (1470, 35)

# %%
df.info() #To get infortmation about Attributes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#Check for duplicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#printing the unique values in all  the columns
for column in df.columns:
  print(column,df[column].unique())
  print(50*"*")
# Out:
# Age [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# **************************************************
# Attrition ['Yes' 'No']
# **************************************************
# BusinessTravel ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# **************************************************
# DailyRate [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
#   489  807  827  871  665 1040 1420  240 1280  534 1456  658  142 1127
# ...

# %%
#To get the number of unique values for each Column
df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %% [markdown]
#  'EmployeeCount', 'Over18', 'StandardHours' have only one unique values and 'EmployeeNumber' has 1470 unique values. This features aren't useful for us, So we are going to drop those columns.

# %%
df.drop(['EmployeeCount','Over18','StandardHours','EmployeeNumber'],axis=1,inplace=True)
df.shape
# Out:
# (1470, 31)

# %%
#to use describe function
df.describe().T
# Out:
#                            count          mean          std     min     25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.0
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.0
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.0
# Education                 1470.0      2.912925     1.024165     1.0     2.0
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.0
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.0
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.0
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.0
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.0
# MonthlyIncome             1470.0   6502.931293  4707.956783  1009.0  2911.0
# MonthlyRate               1470.0  14313.103401  7117.786044  2094.0  8047.0
# ...

# %%
##to use describe function for Objects
df.describe(include="object").T
# Out:
#                count unique                     top  freq
# Attrition       1470      2                      No  1233
# BusinessTravel  1470      3           Travel_Rarely  1043
# Department      1470      3  Research & Development   961
# EducationField  1470      6           Life Sciences   606
# Gender          1470      2                    Male   882
# JobRole         1470      9         Sales Executive   326
# MaritalStatus   1470      3                 Married   673
# OverTime        1470      2                      No  1054

# %% [markdown]
# # Is the data balanced?

# %%
df.Attrition.value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
# Calculate the percentage for each Attrition value
print(df.Attrition.value_counts(normalize=True))
df["Attrition"].value_counts().plot(kind="bar")
plt.title("Attrition Distribution")
plt.xlabel("Attrition")
plt.ylabel("Count")
plt.show()
# Out:
# Attrition
# No     0.838776
# Yes    0.161224
# Name: proportion, dtype: float64

# %%
df.head().T
# Out:
#                                         0                       1  \
# Age                                    41                      49
# Attrition                             Yes                      No
# BusinessTravel              Travel_Rarely       Travel_Frequently
# DailyRate                            1102                     279
# Department                          Sales  Research & Development
# DistanceFromHome                        1                       8
# Education                               2                       1
# EducationField              Life Sciences           Life Sciences
# EnvironmentSatisfaction                 2                       3
# Gender                             Female                    Male
# HourlyRate                             94                      61
# JobInvolvement                          3                       2
# JobLevel                                2                       2
# ...

# %% [markdown]
# # **Data Visualization**

# %%
df.head(10).plot(
    kind='bar',
    x='Department',
    y='YearsAtCompany',
    title='Years at Company by Department',
    xlabel='Department',
    ylabel='Years at Company',
    figsize=(10, 6),
    color=['lightblue','orange','purple','green','red','pink','black','brown','skyblue','yellow']
)
plt.show()

# %%
df.head(10).plot(
    kind='bar',
    x='JobRole',
    y='DistanceFromHome',
    title='Distance From Home by Job Role',
    xlabel='Job Role',
    ylabel='Distance From Home',
    figsize=(10, 6),
    color=['cyan','magenta','lime','coral','gold','violet','navy','salmon','teal','orchid']
)
plt.show()

# %%
df.head(10).plot(
    kind='scatter',
    x='DistanceFromHome',
    y='YearsAtCompany',
    title='Years at Company vs Distance From Home',
    xlabel='Distance From Home',
    ylabel='Years at Company',
    figsize=(10, 6),
    color='red'
)
plt.show()

# %%
df.head(10)['MonthlyIncome'].plot(
    kind='hist',
    bins=5,
    title='Distribution of Monthly Income',
    xlabel='Monthly Income',
    ylabel='Frequency',
    figsize=(10, 6),
    color='orange'
)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# %%
plt.figure(figsize=(16, 10))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap for Numeric Columns")
plt.show()

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

# %%
plt.figure(figsize=(18, 8))
rows = 2
cols = (len(numeric_cols) + 1) // 2

for i, col in enumerate(numeric_cols, 1):
    plt.subplot(rows, cols, i)
    sns.boxplot(y=df[col], color=sns.color_palette("Set2")[i % 8])
    plt.title(col, fontsize=10)

plt.tight_layout()
plt.show()
